# %%
pip install flask-cors
# Out:
# ...
#   Using cached flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wikipedia
# Out:
# ...
#   Using cached wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11704 sha256=c52efdfb7b704721181d7a994c26740b79bc84eed2ed04bb0478db4916594536
#   Stored in directory: c:\users\moham\appdata\local\pip\cache\wheels\79\1d\c8\b64e19423cc5a2a339450ea5d145e7c8eb3d4aa2b150cde33b
# Successfully built wikipedia
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
